# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits import mplot3d

# %%
df = pd.read_csv('/Users/congxiaozhang/Documents/Master Thesis/Thesis/test_data/test data with wide stepsize/odd series/zeta_omega_fiveTerms_testdat.csv')

# %%
df
# Out:
#      zeta  omega_ratio  solution_1  solution_2  solution_3  solution_4  \
# 0    0.01         0.01    1.000204   -0.046294    0.044747   -0.006178
# 1    0.01         0.06    1.002167   -0.049005    0.046009   -0.006864
# 2    0.01         0.11    0.223481    0.237488    0.252915    0.540320
# 3    0.01         0.16    0.365093    0.341524    0.667773   -0.258977
# 4    0.01         0.21    0.000004    1.144444   -0.000001   -0.000001
# ..    ...          ...         ...         ...         ...         ...
# 395  0.96         0.76    0.978218    0.044926    0.004227   -0.017098
# 396  0.96         0.81    1.121162   -0.100452   -0.031896    0.004865
# 397  0.96         0.86    0.939648    0.030740    0.040980   -0.013518
# 398  0.96         0.91    1.188895   -0.226835    0.039655   -0.004666
# 399  0.96         0.96    1.060173   -0.051105   -0.003652    0.005856
#
#      solution_5     power  test_FLAG
# 0      0.007526 -0.003755      False
# 1      0.007698 -0.022346      False
# ...

# %%
zeta = np.array(df.zeta)
#type(zeta)
OR = np.array(df.omega_ratio)
#type(OR)
power = np.array(df.power)
#type(power)
flag = np.array(df.test_FLAG)
#flag

# %%
z = zeta.reshape(20,20)
ratio = OR.reshape(20,20)
P = power.reshape(20,20)
f = flag.reshape(20,20)

# %%
#plot section

plt.xlabel('zeta')
plt.ylabel('Omega Ratio')
plt.title('test data with wide stepsize;odd series;fiveTerms case')

im = plt.contourf(z,ratio,P)
plt.colorbar(im)
for i in range(0,20):
    for j in range(0,20):
        if f[i,j] == True:
            plt.plot(z[i,j],ratio[i,j], ".", markersize=10, color = "#483D8B")
        #else:
        #    plt.plot(z[i,j],ratio[i,j], ".", markersize=10, color = "#8B2323")

plt.tight_layout()
#plt.savefig('test_plot_OS_fiveTerms')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(z, ratio, P,cmap='viridis', edgecolor='none')
